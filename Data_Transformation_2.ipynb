# %%
# !pip install --upgrade statsmodels  dask[dataframe]
# Out:
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (0.14.4)
# Requirement already satisfied: dask[dataframe] in /usr/local/lib/python3.11/dist-packages (2025.2.0)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (24.2)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (8.1.8)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (2025.2.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (1.0.0)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (8.6.1)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (19.0.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata>=4.13.0->dask[dataframe]) (3.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/dist-packages (from partd>=1.4.0->dask[dataframe]) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)

# %%
import pandas as pd
import dask.dataframe as dd
from enum import unique
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import statsmodels.api as sm

# %%
# Connecting to googledrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ruta = '/content/drive/MyDrive/celes_test/data_challenge_preprocess.parquet'
df = dd.read_parquet(ruta,
                     parse_dates=["Date"],
                     engine = 'pyarrow'
                 )

# Sort by Date to maintain time series order
df = df.sort_values("Date").persist()

# Verify sorting
df.shape[0].compute()
# Out:
# 4978868

# %%
df.compute()
# Out:
#               Date     ProductID       StoreID  \
# 0       2022-08-01  2e86ec5da9dd  4b429145d0d6
# 4501    2022-08-01  1f28832cd0d2  dd0ce0c8cfa2
# 4500    2022-08-01  463bb3d2c83a  14d166b132ac
# 4499    2022-08-01  ac82e2ce8e0a  dd0ce0c8cfa2
# 4498    2022-08-01  88f2a8f8004d  7eb078ba1297
# ...            ...           ...           ...
# 4975358 2024-09-25  77b0b19616b7  702c4fdea66b
# 4975357 2024-09-25  93c66d7ed8c6  3b645acc7bbe
# 4975356 2024-09-25  463bb3d2c83a  702c4fdea66b
# 4975354 2024-09-25  e6dc17d84357  8ecfffa75c21
# 4978867 2024-09-25  cdf98587cd38  6c6d5897eb89
#
#                                        ProductName  Quantity        Price  \
# 0              Ebiten maki and Pepper Black Coarse    0.9234     8.033580
# 4501             Salmon nigiri and Allspice Ground    0.9234  2941.029000
# 4500                      Cheeseburger and Amchoor   44.3232     7.294860
# 4499             Vegetable Soup and Paprika Smoked    0.9234  5811.879600
# 4498            Fettuccine Alfredo and Lemon Grass    0.9234  6898.721400
# ...                                            ...       ...          ...
# 4975358  Pasta with Tomato and Basil and Curry Hot    0.9234     5.087934
# 4975357     Chicken milanese and Peppercorns White    0.9234     7.433370
# 4975356                   Cheeseburger and Amchoor   22.1616     3.834418
# 4975354        Califlower penne and Pimento Ground    0.9234     6.020568
# 4978867                  Ebiten maki and Curry Hot  188.3736  1233.784615
#
#          Month  Year  Weekday  week_of_year year_month
# 0            8  2022        0            31    2022-08
# 4501         8  2022        0            31    2022-08
# 4500         8  2022        0            31    2022-08
# 4499         8  2022        0            31    2022-08
# 4498         8  2022        0            31    2022-08
# ...        ...   ...      ...           ...        ...
# 4975358      9  2024        2            39    2024-09
# 4975357      9  2024        2            39    2024-09
# 4975356      9  2024        2            39    2024-09
# 4975354      9  2024        2            39    2024-09
# 4978867      9  2024        2            39    2024-09
#
# [4978868 rows x 11 columns]

# %% [markdown]
# ### Convert Date column to date format

# %%
df['Date'] = dd.to_datetime(df['Date'], format = '%Y-%m-%d')

# %% [markdown]
# ### monthly products

# %%
monthly_products = df.groupby(['Year', 'Month', 'ProductID']).agg(
    {"Quantity": "sum"}).sort_values(
        by = ['Year', 'Month','Quantity'], ascending = False).reset_index()

# %%
monthly_products.shape[0].compute()
# Out:
# 4852

# %%
monthly_products.compute()
# Out:
#       Year  Month     ProductID     Quantity
# 0     2024      9  463bb3d2c83a  184912.6968
# 1     2024      9  16a562fb5931   49220.9136
# 2     2024      9  f9e43b9a154e   30807.3942
# 3     2024      9  93c66d7ed8c6   19115.3034
# 4     2024      9  77b0b19616b7   18601.8930
# ...    ...    ...           ...          ...
# 4847  2022      8  ad2ebfee51bf       0.9234
# 4848  2022      8  adeba912ff56       0.9234
# 4849  2022      8  b4a68da8b9e5       0.9234
# 4850  2022      8  dfef298b305e       0.9234
# 4851  2022      8  b4daa9e5bd37       0.9234
#
# [4852 rows x 4 columns]

# %%
# Group by 'Year' and 'Month' and take the first 10 rows for each group
first_10_per_month = monthly_products.groupby(['Year', 'Month']).head(10).sort_values(
        by = ['Year', 'Month','Quantity'], ascending = False)

# If you need to materialize the result, compute it:
first_10_per_month.compute()
# Out:
#       Year  Month     ProductID     Quantity
# 0     2024      9  463bb3d2c83a  184912.6968
# 1     2024      9  16a562fb5931   49220.9136
# 2     2024      9  f9e43b9a154e   30807.3942
# 3     2024      9  93c66d7ed8c6   19115.3034
# 4     2024      9  77b0b19616b7   18601.8930
# ...    ...    ...           ...          ...
# 4662  2022      8  98a7469435bb   10387.3266
# 4663  2022      8  59c2de4b66d6    8673.4962
# 4664  2022      8  e6dc17d84357    8178.5538
# 4665  2022      8  0a15b6462cf0    7824.8916
# 4666  2022      8  77b0b19616b7    5623.5060
#
# [260 rows x 4 columns]

# %%
first_10_per_month = first_10_per_month.compute() # Materialize the result to avoid issues with delayed computation

# %%
first_10_per_month['Top_10'] = 1

# %%
first_10_per_month.head()
# Out:
#    Year  Month     ProductID     Quantity  Top_10
# 0  2024      9  463bb3d2c83a  184912.6968       1
# 1  2024      9  16a562fb5931   49220.9136       1
# 2  2024      9  f9e43b9a154e   30807.3942       1
# 3  2024      9  93c66d7ed8c6   19115.3034       1
# 4  2024      9  77b0b19616b7   18601.8930       1

# %%
df_promo = first_10_per_month[['Year', 'Month', 'ProductID', 'Top_10']].copy()
df_promo['Year'] = df_promo['Year'] + 1
df_promo = df_promo.rename(columns={'Top_10': 'Promotion'})

# %%
df_promo.head()
# Out:
#    Year  Month     ProductID  Promotion
# 0  2025      9  463bb3d2c83a          1
# 1  2025      9  16a562fb5931          1
# 2  2025      9  f9e43b9a154e          1
# 3  2025      9  93c66d7ed8c6          1
# 4  2025      9  77b0b19616b7          1

# %%
# Merge to mark rows that should have the promotion.
monthly_products = monthly_products.merge(df_promo, on=['Year', 'Month', 'ProductID'], how='left')
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/multi.py:169: UserWarning: Merging dataframes with merge column data type mismatches:
# +--------------------+------------+-------------+
# | Merge columns      | left dtype | right dtype |
# +--------------------+------------+-------------+
# | ('Year', 'Year')   | float64    | int32       |
# | ('Month', 'Month') | float64    | int32       |
# +--------------------+------------+-------------+
# Cast dtypes explicitly to avoid unexpected results.
#   warnings.warn(

# %%
monthly_products.head()
# Out:
#    Year  Month     ProductID     Quantity  Promotion
# 0  2024      9  463bb3d2c83a  184912.6968        1.0
# 1  2024      9  16a562fb5931   49220.9136        1.0
# 2  2024      9  f9e43b9a154e   30807.3942        1.0
# 3  2024      9  93c66d7ed8c6   19115.3034        1.0
# 4  2024      9  77b0b19616b7   18601.8930        1.0

# %%
monthly_products['Promotion'] = monthly_products['Promotion'].fillna(0)

# %%
monthly_products.compute()
# Out:
#       Year  Month     ProductID     Quantity  Promotion
# 0     2024      9  463bb3d2c83a  184912.6968        1.0
# 1     2024      9  16a562fb5931   49220.9136        1.0
# 2     2024      9  f9e43b9a154e   30807.3942        1.0
# 3     2024      9  93c66d7ed8c6   19115.3034        1.0
# 4     2024      9  77b0b19616b7   18601.8930        1.0
# ...    ...    ...           ...          ...        ...
# 4847  2022      8  ad2ebfee51bf       0.9234        0.0
# 4848  2022      8  adeba912ff56       0.9234        0.0
# 4849  2022      8  b4a68da8b9e5       0.9234        0.0
# 4850  2022      8  dfef298b305e       0.9234        0.0
# 4851  2022      8  b4daa9e5bd37       0.9234        0.0
#
# [4852 rows x 5 columns]

# %% [markdown]
# ### Generating promotions

# %%
store_product_monthly = df.groupby(['StoreID', 'ProductID', 'Year', 'Month']).agg(
    {"Quantity": "sum", 'Price': 'median'}).reset_index()

# %%
store_product_monthly.shape[0].compute()
# Out:
# 179775

# %%
store_product_monthly = store_product_monthly.merge(monthly_products[['Year', 'Month', 'ProductID', 'Promotion']],
              on=['ProductID', 'Year', 'Month'], how='left')

# %%
store_product_monthly.shape[0].compute()
# Out:
# 179775

# %%
store_product_monthly['Promotion'].value_counts().compute()
# Out:
# Promotion
# 0.0    168866
# 1.0     10909
# Name: count, dtype: int64

# %%
store_product_monthly = store_product_monthly.assign(
    Price_Promo = store_product_monthly['Price'].where(store_product_monthly['Promotion']==0, store_product_monthly['Price'] * 0.85)
)

# %%
store_product_monthly[(store_product_monthly['Promotion'] == 1) & (store_product_monthly['Year'] == 2023)].head()
# Out:
#             StoreID     ProductID  Year  Month   Quantity        Price  \
# 78506  90f0f4bb4d8f  463bb3d2c83a  2023      8   211.4586     5.475762
# 78507  7b247f240c80  463bb3d2c83a  2023      8   123.7356     5.335713
# 78509  d3d274df729b  463bb3d2c83a  2023      8   473.7042     8.033580
# 78510  250e620ccc15  f9e43b9a154e  2023      8  2078.5734  1233.777825
# 78513  18451d418d52  463bb3d2c83a  2023      8  3437.8182     5.320836
#
#        Promotion  Price_Promo
# 78506        1.0     4.654398
# 78507        1.0     4.535356
# 78509        1.0     6.828543
# 78510        1.0  1048.711151
# 78513        1.0     4.522711

# %% [markdown]
# ### Creating the variable Year-Month as a Date variable from the variables Year and Month

# %%
# Creating the variable Year-Month from the variables Year and Month
store_product_monthly['Year-Month'] = dd.to_datetime(store_product_monthly[['Year', 'Month']].assign(day=1))

# %% [markdown]
# ### Checking null values

# %%
store_product_monthly.isnull().sum().compute()/store_product_monthly.shape[0].compute()
# Out:
# StoreID        0.0
# ProductID      0.0
# Year           0.0
# Month          0.0
# Quantity       0.0
# Price          0.0
# Promotion      0.0
# Price_Promo    0.0
# Year-Month     0.0
# dtype: float64

# %% [markdown]
# ### Selecting final variables to the model

# %%
final_variables = ['Year-Month', 'ProductID', 'StoreID', 'Quantity', 'Promotion', 'Price','Price_Promo']
df_final = store_product_monthly[final_variables]
df_final.head()
# Out:
#   Year-Month     ProductID       StoreID   Quantity  Promotion       Price  \
# 0 2022-08-01  2e86ec5da9dd  4b429145d0d6  1432.1934        0.0     8.21826
# 1 2022-08-01  1f28832cd0d2  dd0ce0c8cfa2     2.7702        0.0  2646.46440
# 2 2022-08-01  463bb3d2c83a  14d166b132ac  7458.3018        0.0     7.29486
# 3 2022-08-01  ac82e2ce8e0a  dd0ce0c8cfa2   117.2718        0.0  5811.87960
# 4 2022-08-01  88f2a8f8004d  7eb078ba1297    35.0892        0.0  6898.72140
#
#    Price_Promo
# 0      8.21826
# 1   2646.46440
# 2      7.29486
# 3   5811.87960
# 4   6898.72140

# %%
df_final.to_parquet('/content/drive/MyDrive/celes_test/data-challenge-final-selection.parquet')
